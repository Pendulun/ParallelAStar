# %%
import networkx as nx
import scipy
import statistics
import matplotlib.pyplot as plt
from random import seed
from random import randint

# %%
G = nx.random_geometric_graph(20, 0.1, seed=123)

# %%
for node in G.nodes(data=True):
    #print(node[0])
    print(node[1]['pos'][0])
# Out:
# [0.052363598850944326, 0.08718667752263232]
# [0.4072417636703983, 0.10770023493843905]
# [0.9011988779516946, 0.0381536661023224]
# [0.5362020400339269, 0.33219769850967984]
# [0.8520866189293687, 0.1596623967219699]
# [0.3372166571092755, 0.3337963946289553]
# [0.24516335251761112, 0.0016705535792228554]
# [0.4362757934152184, 0.08761349975042287]
# [0.5975994644879905, 0.06987696145918243]
# [0.3154589737358633, 0.44832170830694373]
# [0.9053986522844989, 0.09276456137849509]
# [0.14217506443150107, 0.7900718443588016]
# [0.021235974816989245, 0.9111505480903207]
# [0.5734080856809272, 0.2653217052615633]
# [0.8378376441951344, 0.7687947474799836]
# [0.3434621581559646, 0.801496591292033]
# [0.2068624706661114, 0.6089025261905533]
# [0.5270749521614166, 0.8093385246438048]
# [0.3152631522159881, 0.3982381514678992]
# [0.7692790899139238, 0.512752133864065]

# %%
def getPValues(gType='geometrical'):
    pValues = []
    probs =      [0.125, 0.125, 0.125, 0.1,  0.05,  0.04,  0.03,  0.02,  0.01]
    radius =     [0.1,   0.1,   0.05,   0.05,  0.02,  0.02,  0.02,  0.01,  0.01]

    if gType == 'geometrical':
        pValues = radius
        print("Usou radius!")
    elif gType == 'probabilistic':
        pValues = probs
        print("Usou probs!")

    return pValues

def generateGraph(gType='geometrical', gSize = 50, pValue=0.1, isDirected=False, gSeed = 123):
    G = 0
    if gType == 'geometrical':
        G = nx.random_geometric_graph(gSize, pValue, seed=gSeed)
    elif gType == 'probabilistic':
        G = nx.erdos_renyi_graph(gSize, pValue, seed=gSeed, directed=isDirected)
    
    return G

def getLargestSubGraph(G):
    largest_cc = max(nx.connected_components(G), key=len)
    largest_cc_graph = G.subgraph(largest_cc).copy()
    return largest_cc_graph

def drawAndSave(G, outName):
    plt.figure(figsize=(12, 10))
    print(f"Desenhando grafo {outName}")
    nx.draw(G, node_size=50, cmap=plt.cm.Reds_r, )
    plt.savefig(f"graph{len(G.nodes)}.png")
    print("Terminou de desenhar")
    
def printGraphStats(G):
    gTotalSize = len(G.nodes)
    gNumEdges = len(G.edges)
    meanEdgePerNode = round(gNumEdges/gTotalSize,2)
    maxDegree = 0
    degrees = []
    for nodeDegreePair in list(G.degree):
        degrees.append(nodeDegreePair[1])
        if nodeDegreePair[1] > maxDegree:
            maxDegree = nodeDegreePair[1]
    
    meanDegree = round(statistics.mean(degrees),2)
    degreesStDev = round(statistics.stdev(degrees),2)
    quantis = [round(q, 1) for q in statistics.quantiles(degrees, n=4)]
    print(f"Graph num Nodes: {gTotalSize}, num edges:{gNumEdges}, Mean Edge Per Node: {meanEdgePerNode}")
    print(f"Graph density: {nx.density(G)}")
    print(f"Degree stats: {meanDegree}(+-{degreesStDev}), Max degree: {maxDegree}, Quantis: {quantis}")

def saveNodesInfo(G, outFileName):
    with open(outFileName, "w") as nodePosFile:
        for node in G.nodes(data=True):
            nodeCoords = node[1]['pos']
            nodeId = node[0]
            nodePosFile.write(f"{nodeId},{nodeCoords[0]},{nodeCoords[1]}\n")

def saveEdgesInfo(G, outFileName):
    with open(outFileName, "w") as outFile:
        print("Iterando pelas arestas")
        for edge in G.edges:
            randomWeight = randint(0, 100)
            outFile.write(f"{edge[0]},{edge[1]},{randomWeight}\n")
            outFile.write(f"{edge[1]},{edge[0]},{randomWeight}\n")
    print(f"Terminou de salvar dados de {outFileName}")



def createAndSaveGraphs(graphType, graphSizes):     
    pValues = getPValues(graphType)
    seed(100)
    for idx, graphSize in enumerate(graphSizes):
        print(f"----GERANDO NOVO GRAFO!----")
        G = generateGraph(graphType, graphSize, pValues[idx])
        G = getLargestSubGraph(G)

        gTotalSize = len(G.nodes)
        printGraphStats(G)
        if graphType == 'geometrical':
            #printar localização dos nós
            outFileName = "nodePosGraph"+str(gTotalSize)+".txt"
            saveNodesInfo(G, outFileName)


        outFileName = "teste"+str(gTotalSize)+".txt"
        if(gTotalSize <= 1000):
            drawAndSave(G, outFileName)

        saveEdgesInfo(G, outFileName)

# %%
graphType = 'geometrical'
graphSizes = [100,   1000,  2000,  5000, 10000, 30000, 50000, 80000, 100000]
createAndSaveGraphs(graphType, graphSizes)
# Out:
# Usou radius!
# ----GERANDO NOVO GRAFO!----
# Graph num Nodes: 48, num edges:92, Mean Edge Per Node: 1.92
# Graph density: 0.08156028368794327
# Degree stats: 3.83(+-1.64), Max degree: 7, Quantis: [3.0, 3.0, 5.0]
# Desenhando grafo teste48.txt
# Terminou de desenhar
# Iterando pelas arestas
# Terminou de salvar dados de teste48.txt
# ----GERANDO NOVO GRAFO!----
# Graph num Nodes: 1000, num edges:14321, Mean Edge Per Node: 14.32
# Graph density: 0.02867067067067067
# Degree stats: 28.64(+-7.06), Max degree: 49, Quantis: [24.0, 29.0, 33.0]
# Desenhando grafo teste1000.txt
# Terminou de desenhar
# Iterando pelas arestas
# Terminou de salvar dados de teste1000.txt
# ----GERANDO NOVO GRAFO!----
# Graph num Nodes: 2000, num edges:15131, Mean Edge Per Node: 7.57
# Graph density: 0.007569284642321161
# Degree stats: 15.13(+-4.47), Max degree: 32, Quantis: [12.0, 15.0, 18.0]
# Iterando pelas arestas
# Terminou de salvar dados de teste2000.txt
# ----GERANDO NOVO GRAFO!----
# Graph num Nodes: 5000, num edges:94088, Mean Edge Per Node: 18.82
# Graph density: 0.007528545709141829
# Degree stats: 37.64(+-7.45), Max degree: 64, Quantis: [33.0, 38.0, 42.0]
# Iterando pelas arestas
# Terminou de salvar dados de teste5000.txt
# ----GERANDO NOVO GRAFO!----
# Graph num Nodes: 10000, num edges:61707, Mean Edge Per Node: 6.17
# Graph density: 0.0012342634263426344
# Degree stats: 12.34(+-3.61), Max degree: 27, Quantis: [10.0, 12.0, 15.0]
# Iterando pelas arestas
# Terminou de salvar dados de teste10000.txt
# ----GERANDO NOVO GRAFO!----
# Graph num Nodes: 30000, num edges:556544, Mean Edge Per Node: 18.55
# Graph density: 0.0012368056713001545
# Degree stats: 37.1(+-6.7), Max degree: 64, Quantis: [33.0, 37.0, 42.0]
# Iterando pelas arestas
# Terminou de salvar dados de teste30000.txt
# ----GERANDO NOVO GRAFO!----
# Graph num Nodes: 50000, num edges:1544624, Mean Edge Per Node: 30.89
# Graph density: 0.0012357239144782895
# Degree stats: 61.78(+-9.02), Max degree: 98, Quantis: [57.0, 62.0, 68.0]
# Iterando pelas arestas
# Terminou de salvar dados de teste50000.txt
# ----GERANDO NOVO GRAFO!----
# Graph num Nodes: 80000, num edges:998327, Mean Edge Per Node: 12.48
# Graph density: 0.0003119810872635908
# Degree stats: 24.96(+-5.17), Max degree: 51, Quantis: [21.0, 25.0, 28.0]
# Iterando pelas arestas
# Terminou de salvar dados de teste80000.txt
# ----GERANDO NOVO GRAFO!----
# Graph num Nodes: 100000, num edges:1559440, Mean Edge Per Node: 15.59
# Graph density: 0.0003118911189111891
# Degree stats: 31.19(+-5.82), Max degree: 55, Quantis: [27.0, 31.0, 35.0]
# Iterando pelas arestas
# Terminou de salvar dados de teste100000.txt
